# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df1=pd.read_csv("https://raw.githubusercontent.com/Divyashanmugapriyan/Dataset/main/takehome_users.csv",encoding='unicode_escape')
df1
# Out:
#        object_id        creation_time               name  \
# 0              1  2014-04-22 03:53:30     Clausen August
# 1              2  2013-11-15 03:45:04      Poole Matthew
# 2              3  2013-03-19 23:14:52  Bottrill Mitchell
# 3              4  2013-05-21 08:09:28    Clausen Nicklas
# 4              5  2013-01-17 10:14:20          Raw Grace
# ...          ...                  ...                ...
# 11995      11996  2013-09-06 06:14:15       Meier Sophia
# 11996      11997  2013-01-10 18:28:37      Fisher Amelie
# 11997      11998  2014-04-27 12:45:16        Haynes Jake
# 11998      11999  2012-05-31 11:55:59       Faber Annett
# 11999      12000  2014-01-26 08:57:12         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# 4              GraceRaw@yahoo.com        GUEST_INVITE
# ...                           ...                 ...
# 11995       SophiaMeier@gustr.com          ORG_INVITE
# 11996      AmelieFisher@gmail.com  SIGNUP_GOOGLE_AUTH
# 11997         JakeHaynes@cuvox.de        GUEST_INVITE
# 11998          mhaerzxp@iuxiw.com   PERSONAL_PROJECTS
# 11999   ThaisMeloLima@hotmail.com              SIGNUP
#
#        last_session_creation_time  opted_in_to_mailing_list  \
# 0                    1.398139e+09                         1
# 1                    1.396238e+09                         0
# 2                    1.363735e+09                         0
# 3                    1.369210e+09                         0
# 4                    1.358850e+09                         0
# ...                           ...                       ...
# 11995                1.378448e+09                         0
# 11996                1.358275e+09                         0
# 11997                1.398603e+09                         1
# 11998                1.338638e+09                         0
# 11999                1.390727e+09                         0
#
#        enabled_for_marketing_drip  org_id  invited_by_user_id
# 0                               0      11             10803.0
# 1                               0       1               316.0
# 2                               0      94              1525.0
# 3                               0       1              5151.0
# 4                               0     193              5240.0
# ...                           ...     ...                 ...
# 11995                           0      89              8263.0
# 11996                           0     200                 NaN
# 11997                           1      83              8074.0
# 11998                           0       6                 NaN
# 11999                           1       0                 NaN
#
# [12000 rows x 10 columns]

# %%
df1.rename(columns={"object_id":"user_id"},inplace=True)
df1
# Out:
#        user_id        creation_time               name  \
# 0            1  2014-04-22 03:53:30     Clausen August
# 1            2  2013-11-15 03:45:04      Poole Matthew
# 2            3  2013-03-19 23:14:52  Bottrill Mitchell
# 3            4  2013-05-21 08:09:28    Clausen Nicklas
# 4            5  2013-01-17 10:14:20          Raw Grace
# ...        ...                  ...                ...
# 11995    11996  2013-09-06 06:14:15       Meier Sophia
# 11996    11997  2013-01-10 18:28:37      Fisher Amelie
# 11997    11998  2014-04-27 12:45:16        Haynes Jake
# 11998    11999  2012-05-31 11:55:59       Faber Annett
# 11999    12000  2014-01-26 08:57:12         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# 4              GraceRaw@yahoo.com        GUEST_INVITE
# ...                           ...                 ...
# 11995       SophiaMeier@gustr.com          ORG_INVITE
# 11996      AmelieFisher@gmail.com  SIGNUP_GOOGLE_AUTH
# 11997         JakeHaynes@cuvox.de        GUEST_INVITE
# 11998          mhaerzxp@iuxiw.com   PERSONAL_PROJECTS
# 11999   ThaisMeloLima@hotmail.com              SIGNUP
#
#        last_session_creation_time  opted_in_to_mailing_list  \
# 0                    1.398139e+09                         1
# 1                    1.396238e+09                         0
# 2                    1.363735e+09                         0
# 3                    1.369210e+09                         0
# 4                    1.358850e+09                         0
# ...                           ...                       ...
# 11995                1.378448e+09                         0
# 11996                1.358275e+09                         0
# 11997                1.398603e+09                         1
# 11998                1.338638e+09                         0
# 11999                1.390727e+09                         0
#
#        enabled_for_marketing_drip  org_id  invited_by_user_id
# 0                               0      11             10803.0
# 1                               0       1               316.0
# 2                               0      94              1525.0
# 3                               0       1              5151.0
# 4                               0     193              5240.0
# ...                           ...     ...                 ...
# 11995                           0      89              8263.0
# 11996                           0     200                 NaN
# 11997                           1      83              8074.0
# 11998                           0       6                 NaN
# 11999                           1       0                 NaN
#
# [12000 rows x 10 columns]

# %%
df1["invited_by_user_id"].value_counts().sum()
# Out:
# 6417

# %%
df1.rename(columns={"object_id":"user_id"},inplace=True)

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/Divyashanmugapriyan/Dataset/main/takehome_user_engagement.csv")
df2
# Out:
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 1       2013-11-15 03:45:04        2        1
# 2       2013-11-29 03:45:04        2        1
# 3       2013-12-09 03:45:04        2        1
# 4       2013-12-25 03:45:04        2        1
# ...                     ...      ...      ...
# 207912  2013-09-06 06:14:15    11996        1
# 207913  2013-01-15 18:28:37    11997        1
# 207914  2014-04-27 12:45:16    11998        1
# 207915  2012-06-02 11:55:59    11999        1
# 207916  2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]

# %%
df2.isna().sum()
# Out:
# time_stamp    0
# user_id       0
# visited       0
# dtype: int64

# %% [markdown]
# #merge datasets

# %%
Data=pd.merge(df1,df2,on='user_id',how='right')
Data
# Out:
#         user_id        creation_time            name  \
# 0             1  2014-04-22 03:53:30  Clausen August
# 1             2  2013-11-15 03:45:04   Poole Matthew
# 2             2  2013-11-15 03:45:04   Poole Matthew
# 3             2  2013-11-15 03:45:04   Poole Matthew
# 4             2  2013-11-15 03:45:04   Poole Matthew
# ...         ...                  ...             ...
# 207912    11996  2013-09-06 06:14:15    Meier Sophia
# 207913    11997  2013-01-10 18:28:37   Fisher Amelie
# 207914    11998  2014-04-27 12:45:16     Haynes Jake
# 207915    11999  2012-05-31 11:55:59    Faber Annett
# 207916    12000  2014-01-26 08:57:12      Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2          MatthewPoole@gustr.com          ORG_INVITE
# 3          MatthewPoole@gustr.com          ORG_INVITE
# 4          MatthewPoole@gustr.com          ORG_INVITE
# ...                           ...                 ...
# 207912      SophiaMeier@gustr.com          ORG_INVITE
# 207913     AmelieFisher@gmail.com  SIGNUP_GOOGLE_AUTH
# 207914        JakeHaynes@cuvox.de        GUEST_INVITE
# 207915         mhaerzxp@iuxiw.com   PERSONAL_PROJECTS
# 207916  ThaisMeloLima@hotmail.com              SIGNUP
#
#         last_session_creation_time  opted_in_to_mailing_list  \
# 0                     1.398139e+09                         1
# 1                     1.396238e+09                         0
# 2                     1.396238e+09                         0
# 3                     1.396238e+09                         0
# 4                     1.396238e+09                         0
# ...                            ...                       ...
# 207912                1.378448e+09                         0
# 207913                1.358275e+09                         0
# 207914                1.398603e+09                         1
# 207915                1.338638e+09                         0
# 207916                1.390727e+09                         0
#
#         enabled_for_marketing_drip  org_id  invited_by_user_id  \
# 0                                0      11             10803.0
# 1                                0       1               316.0
# 2                                0       1               316.0
# 3                                0       1               316.0
# 4                                0       1               316.0
# ...                            ...     ...                 ...
# 207912                           0      89              8263.0
# 207913                           0     200                 NaN
# 207914                           1      83              8074.0
# 207915                           0       6                 NaN
# 207916                           1       0                 NaN
#
#                  time_stamp  visited
# 0       2014-04-22 03:53:30        1
# 1       2013-11-15 03:45:04        1
# 2       2013-11-29 03:45:04        1
# 3       2013-12-09 03:45:04        1
# 4       2013-12-25 03:45:04        1
# ...                     ...      ...
# 207912  2013-09-06 06:14:15        1
# 207913  2013-01-15 18:28:37        1
# 207914  2014-04-27 12:45:16        1
# 207915  2012-06-02 11:55:59        1
# 207916  2014-01-26 08:57:12        1
#
# [207917 rows x 12 columns]

# %%
#converting the datatypes
Data['creation_time']=pd.to_datetime(Data['creation_time'])
Data['time_stamp']=pd.to_datetime(Data['time_stamp'])
Data['last_session_creation_time']= pd.to_datetime(Data['last_session_creation_time'],unit='s')

# %%
Data.isna().sum() # check for Nan values
# Out:
# user_id                           0
# creation_time                     0
# name                              0
# email                             0
# creation_source                   0
# last_session_creation_time        0
# opted_in_to_mailing_list          0
# enabled_for_marketing_drip        0
# org_id                            0
# invited_by_user_id            91030
# time_stamp                        0
# visited                           0
# dtype: int64

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207917 entries, 0 to 207916
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   user_id                     207917 non-null  int64
#  1   creation_time               207917 non-null  datetime64[ns]
#  2   name                        207917 non-null  object
#  3   email                       207917 non-null  object
#  4   creation_source             207917 non-null  object
#  5   last_session_creation_time  207917 non-null  datetime64[ns]
#  6   opted_in_to_mailing_list    207917 non-null  int64
#  7   enabled_for_marketing_drip  207917 non-null  int64
#  8   org_id                      207917 non-null  int64
#  9   invited_by_user_id          116887 non-null  float64
#  10  time_stamp                  207917 non-null  datetime64[ns]
#  11  visited                     207917 non-null  int64
# dtypes: datetime64[ns](3), float64(1), int64(5), object(3)
# memory usage: 20.6+ MB

# %%
Data.drop(columns = 'invited_by_user_id',axis=1,inplace=True) #drop unwanted columns

# %%
Data.describe()
# Out:
#              user_id  opted_in_to_mailing_list  enabled_for_marketing_drip  \
# count  207917.000000             207917.000000               207917.000000
# mean     5913.314197                  0.258137                    0.154533
# std      3394.941674                  0.437611                    0.361460
# min         1.000000                  0.000000                    0.000000
# 25%      3087.000000                  0.000000                    0.000000
# 50%      5682.000000                  0.000000                    0.000000
# 75%      8944.000000                  1.000000                    0.000000
# max     12000.000000                  1.000000                    1.000000
#
#               org_id   visited
# count  207917.000000  207917.0
# mean      164.315895       1.0
# std       121.165846       0.0
# min         0.000000       1.0
# 25%        60.000000       1.0
# 50%       145.000000       1.0
# 75%       260.000000       1.0
# max       416.000000       1.0

# %%
Data.count()
# Out:
# user_id                       207917
# creation_time                 207917
# name                          207917
# email                         207917
# creation_source               207917
# last_session_creation_time    207917
# opted_in_to_mailing_list      207917
# enabled_for_marketing_drip    207917
# org_id                        207917
# time_stamp                    207917
# visited                       207917
# dtype: int64

# %%
#creating new columns
Data['week']=Data['last_session_creation_time'].dt.isocalendar().week
Data
# Out:
#         user_id       creation_time            name  \
# 0             1 2014-04-22 03:53:30  Clausen August
# 1             2 2013-11-15 03:45:04   Poole Matthew
# 2             2 2013-11-15 03:45:04   Poole Matthew
# 3             2 2013-11-15 03:45:04   Poole Matthew
# 4             2 2013-11-15 03:45:04   Poole Matthew
# ...         ...                 ...             ...
# 207912    11996 2013-09-06 06:14:15    Meier Sophia
# 207913    11997 2013-01-10 18:28:37   Fisher Amelie
# 207914    11998 2014-04-27 12:45:16     Haynes Jake
# 207915    11999 2012-05-31 11:55:59    Faber Annett
# 207916    12000 2014-01-26 08:57:12      Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2          MatthewPoole@gustr.com          ORG_INVITE
# 3          MatthewPoole@gustr.com          ORG_INVITE
# 4          MatthewPoole@gustr.com          ORG_INVITE
# ...                           ...                 ...
# 207912      SophiaMeier@gustr.com          ORG_INVITE
# 207913     AmelieFisher@gmail.com  SIGNUP_GOOGLE_AUTH
# 207914        JakeHaynes@cuvox.de        GUEST_INVITE
# 207915         mhaerzxp@iuxiw.com   PERSONAL_PROJECTS
# 207916  ThaisMeloLima@hotmail.com              SIGNUP
#
#        last_session_creation_time  opted_in_to_mailing_list  \
# 0             2014-04-22 03:53:30                         1
# 1             2014-03-31 03:45:04                         0
# 2             2014-03-31 03:45:04                         0
# 3             2014-03-31 03:45:04                         0
# 4             2014-03-31 03:45:04                         0
# ...                           ...                       ...
# 207912        2013-09-06 06:14:15                         0
# 207913        2013-01-15 18:28:37                         0
# 207914        2014-04-27 12:45:16                         1
# 207915        2012-06-02 11:55:59                         0
# 207916        2014-01-26 08:57:12                         0
#
#         enabled_for_marketing_drip  org_id          time_stamp  visited  week
# 0                                0      11 2014-04-22 03:53:30        1    17
# 1                                0       1 2013-11-15 03:45:04        1    14
# 2                                0       1 2013-11-29 03:45:04        1    14
# 3                                0       1 2013-12-09 03:45:04        1    14
# 4                                0       1 2013-12-25 03:45:04        1    14
# ...                            ...     ...                 ...      ...   ...
# 207912                           0      89 2013-09-06 06:14:15        1    36
# 207913                           0     200 2013-01-15 18:28:37        1     3
# 207914                           1      83 2014-04-27 12:45:16        1    17
# 207915                           0       6 2012-06-02 11:55:59        1    22
# 207916                           1       0 2014-01-26 08:57:12        1     4
#
# [207917 rows x 12 columns]

# %%
groupby_week = Data.groupby(['user_id','week','creation_source','opted_in_to_mailing_list','enabled_for_marketing_drip','org_id'])['visited'].count().reset_index()
groupby_week.tail(10)
# Out:
#       user_id  week     creation_source  opted_in_to_mailing_list  \
# 8813    11989    36  SIGNUP_GOOGLE_AUTH                         1
# 8814    11990    27          ORG_INVITE                         0
# 8815    11991    22  SIGNUP_GOOGLE_AUTH                         0
# 8816    11992    15   PERSONAL_PROJECTS                         0
# 8817    11995    43   PERSONAL_PROJECTS                         0
# 8818    11996    36          ORG_INVITE                         0
# 8819    11997     3  SIGNUP_GOOGLE_AUTH                         0
# 8820    11998    17        GUEST_INVITE                         1
# 8821    11999    22   PERSONAL_PROJECTS                         0
# 8822    12000     4              SIGNUP                         0
#
#       enabled_for_marketing_drip  org_id  visited
# 8813                           0      22        1
# 8814                           0      25        1
# 8815                           0     388        5
# 8816                           0     129        1
# 8817                           0       0        1
# 8818                           0      89        1
# 8819                           0     200        1
# 8820                           1      83        1
# 8821                           0       6        1
# 8822                           1       0        1

# %%
#creating a new dataset
adopted_user = groupby_week.loc[groupby_week['visited'] >= 3]
print('Total no of adopted users: ',len(adopted_user))
# Out:
# Total no of adopted users:  2248

# %%
groupby_week['adopted_user'] = groupby_week['visited'].apply(lambda x: 'yes' if x >= 3 else 'No')

# %%
fig=px.bar(groupby_week,x='adopted_user',color='adopted_user')
fig.update_traces(
                  marker_line_width = 0,
                  selector=dict(type="bar"))
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6f22bb72-2b80-41e1-a617-9b5f32b73c92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f22bb72-2b80-41e1-a617-9b5f32b73c92")) {                    Plotly.newPlot(                        "6f22bb72-2b80-41e1-a617-9b5f32b73c92",                        [{"alignmentgroup":"True","hovertemplate":"adopted_user=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""},"line":{"width":0}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No","No" ...

# %%
#Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for column in groupby_week.columns:
  if groupby_week[column].dtype == object:
    groupby_week[column] = le.fit_transform(groupby_week[column])

# %% [markdown]
# #Modelling

# %%
from sklearn.model_selection import train_test_split
X=groupby_week.drop(columns=['user_id','adopted_user','visited'],axis=1)
Y=groupby_week['adopted_user']

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=33)

# %% [markdown]
# Random Forest Clasiifier

# %%
from sklearn.ensemble import RandomForestClassifier 
randomforest=RandomForestClassifier(max_depth=100,n_estimators=13,random_state=123)
randomforest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=100, n_estimators=13, random_state=123)

# %%
y_pred=randomforest.predict(x_test)
score=randomforest.score(x_test,y_test)
score*100
# Out:
# 79.3201133144476

# %%
#XGBoost

from xgboost import XGBClassifier
xgb = XGBClassifier(max_depth=2,n_estimators=240)
xgb.fit(x_train,y_train)
 
xgb_score = xgb.score(x_test,y_test)*100
print("XGBoost  Score is :",xgb_score)
# Out:
# XGBoost  Score is : 84.02266288951841

# %%
#Feature Importance

feature_scores = pd.Series(randomforest.feature_importances_,index=x_train.columns).sort_values(ascending=False)
feature_scores = feature_scores*100
feature_scores
# Out:
# org_id                        48.001900
# week                          44.458415
# creation_source                4.554837
# opted_in_to_mailing_list       1.626260
# enabled_for_marketing_drip     1.358588
# dtype: float64

# %%
#ploting features

plt.figure(figsize=(8,8))
sns.barplot(x=feature_scores,y=feature_scores.index)
plt.show()
